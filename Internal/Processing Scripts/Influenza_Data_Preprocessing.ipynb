# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import datetime

# %% [markdown]
# ### US Data

# %%
ilinet_data = pd.read_csv('F:/Pandemic-Database/Raw_Data/Influenza/ILINet.csv',
                         header= 1)

ilinet_data = ilinet_data[['REGION','YEAR','WEEK','ILITOTAL']]

ilinet_data.insert(0,'Microbe Family','Orthomyxovididae')
ilinet_data.insert(1,'Microbe Genus','Influenza A, B, and C Virus')
ilinet_data.insert(2,'Microbe Species', 'None' )
ilinet_data.insert(3,'Region', 'AMRO' )
ilinet_data.insert(4,'Country', 'United States' )
ilinet_data.insert(6,'Sub-Domain', np.nan )
ilinet_data.insert(7,'date', np.nan )
ilinet_data.insert(8,'type', 'ILI_Total')

ilinet_data = ilinet_data.rename(columns={'REGION':'Domain',
                                         'ILITOTAL':'number'})

ilinet_data['date'] = ilinet_data['YEAR'].astype(str) + '-' + ilinet_data['WEEK'].astype(str) + '-1'

ilinet_data['date'] = ilinet_data['date'].map(lambda x: datetime.datetime.strptime(x, "%Y-%W-%w").date())

ilinet_data = ilinet_data.drop(columns=['YEAR','WEEK'])

ilinet_data
# Out:
#          Microbe Family                Microbe Genus Microbe Species Region  \
# 0      Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
# 1      Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
# 2      Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
# 3      Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
# 4      Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
# ...                 ...                          ...             ...    ...
# 36828  Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
# 36829  Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
# 36830  Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
# 36831  Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
# 36832  Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
#
#              Country                                        Domain  \
# 0      United States                                       Alabama
# 1      United States                                        Alaska
# 2      United States                                       Arizona
# 3      United States                                      Arkansas
# 4      United States                                    California
# ...              ...                                           ...
# 36828  United States                                       Wyoming
# 36829  United States  Commonwealth of the Northern Mariana Islands
# 36830  United States                                   Puerto Rico
# 36831  United States                                Virgin Islands
# 36832  United States                                 New York City
#
#        Sub-Domain        date       type number
# 0             NaN  2010-10-04  ILI_Total    249
# 1             NaN  2010-10-04  ILI_Total     15
# 2             NaN  2010-10-04  ILI_Total    172
# 3             NaN  2010-10-04  ILI_Total     18
# 4             NaN  2010-10-04  ILI_Total    632
# ...           ...         ...        ...    ...
# 36828         NaN  2023-10-23  ILI_Total     68
# 36829         NaN  2023-10-23  ILI_Total      X
# 36830         NaN  2023-10-23  ILI_Total    157
# 36831         NaN  2023-10-23  ILI_Total     22
# 36832         NaN  2023-10-23  ILI_Total   5694
#
# [36833 rows x 10 columns]

# %%
len(set(ilinet_data['Domain']))
# Out:
# 55

# %% [markdown]
# ### World Data

# %%
world_ilinet_data = pd.read_csv('F:/Pandemic-Database/Raw_Data/Influenza/WHO_influenza.csv')
world_ilinet_data = world_ilinet_data.dropna(subset=['Cases of influenza-like illnesses'])
world_ilinet_data = world_ilinet_data[['Country','Day','Cases of influenza-like illnesses']]
world_ilinet_data = world_ilinet_data.reset_index(drop = True)
world_ilinet_data.insert(0,'Microbe Family','Orthomyxovididae')
world_ilinet_data.insert(1,'Microbe Genus','Influenza A, B, and C Virus')
world_ilinet_data.insert(2,'Microbe Species', 'None' )
world_ilinet_data.insert(3,'Region', np.nan )
world_ilinet_data.insert(5,'Domain', np.nan)
world_ilinet_data.insert(6,'Sub-Domain', np.nan)
world_ilinet_data.insert(8,'type', 'Cases')

world_ilinet_data = world_ilinet_data.rename(columns={'Day':'date',
                                                      'Cases of influenza-like illnesses': 'number'})

world_ilinet_data
# Out:
#          Microbe Family                Microbe Genus Microbe Species  Region  \
# 0      Orthomyxovididae  Influenza A, B, and C Virus            None     NaN
# 1      Orthomyxovididae  Influenza A, B, and C Virus            None     NaN
# 2      Orthomyxovididae  Influenza A, B, and C Virus            None     NaN
# 3      Orthomyxovididae  Influenza A, B, and C Virus            None     NaN
# 4      Orthomyxovididae  Influenza A, B, and C Virus            None     NaN
# ...                 ...                          ...             ...     ...
# 68349  Orthomyxovididae  Influenza A, B, and C Virus            None     NaN
# 68350  Orthomyxovididae  Influenza A, B, and C Virus            None     NaN
# 68351  Orthomyxovididae  Influenza A, B, and C Virus            None     NaN
# 68352  Orthomyxovididae  Influenza A, B, and C Virus            None     NaN
# 68353  Orthomyxovididae  Influenza A, B, and C Virus            None     NaN
#
#            Country  Domain  Sub-Domain        date   type  number
# 0      Afghanistan     NaN         NaN  2016-03-14  Cases   494.0
# 1      Afghanistan     NaN         NaN  2016-03-21  Cases   715.0
# 2      Afghanistan     NaN         NaN  2016-03-28  Cases   704.0
# 3      Afghanistan     NaN         NaN  2016-04-04  Cases   749.0
# 4      Afghanistan     NaN         NaN  2016-04-11  Cases   651.0
# ...            ...     ...         ...         ...    ...     ...
# 68349       Zambia     NaN         NaN  2021-11-29  Cases  1866.0
# 68350       Zambia     NaN         NaN  2021-12-06  Cases  1394.0
# 68351       Zambia     NaN         NaN  2021-12-13  Cases  1348.0
# 68352       Zambia     NaN         NaN  2021-12-20  Cases  1513.0
# 68353       Zambia     NaN         NaN  2021-12-27  Cases  1641.0
#
# [68354 rows x 10 columns]

# %%
country_to_region_dict = np.load('F:/Pandemic-Database/Internal/Intermediate_Data_Archive/Country_Region_Dict.npy',
                                 allow_pickle=True).item()

country_to_region_dict.update({'American Samoa':'AMRO',
'Anguilla':'AMRO',
'Bonaire Sint Eustatius and Saba':'AMRO',
'British Virgin Islands':'AMRO',
"Cayman Islands":'AMRO',
"Cote d'Ivoire":'AFRO',
'East Timor':'WPRO',
'French Polynesia':'WPRO',
'Kosovo':'EURO',
'Micronesia (country)':'WPRO',
'Montserrat':'AMRO',
'Northern Mariana Islands':'WPRO',
'Pitcairn':'WPRO',
'Sint Maarten (Dutch part)':'AMRO',
'Tokelau':'WPRO',
'Turks and Caicos Islands':'AMRO',
'Wallis and Futuna':'WPRO'})

np.save('F:/Pandemic-Database/Internal/Intermediate_Data_Archive/Country_Region_Dict.npy', country_to_region_dict)

# %%
world_ilinet_data['Region'] = world_ilinet_data['Country'].map(country_to_region_dict)
world_ilinet_data = world_ilinet_data.dropna(subset=['Region'])
world_ilinet_data['date'] = pd.to_datetime(world_ilinet_data['date']).dt.date
world_ilinet_data
# Out:
#          Microbe Family                Microbe Genus Microbe Species Region  \
# 0      Orthomyxovididae  Influenza A, B, and C Virus            None   EMRO
# 1      Orthomyxovididae  Influenza A, B, and C Virus            None   EMRO
# 2      Orthomyxovididae  Influenza A, B, and C Virus            None   EMRO
# 3      Orthomyxovididae  Influenza A, B, and C Virus            None   EMRO
# 4      Orthomyxovididae  Influenza A, B, and C Virus            None   EMRO
# ...                 ...                          ...             ...    ...
# 68349  Orthomyxovididae  Influenza A, B, and C Virus            None   AFRO
# 68350  Orthomyxovididae  Influenza A, B, and C Virus            None   AFRO
# 68351  Orthomyxovididae  Influenza A, B, and C Virus            None   AFRO
# 68352  Orthomyxovididae  Influenza A, B, and C Virus            None   AFRO
# 68353  Orthomyxovididae  Influenza A, B, and C Virus            None   AFRO
#
#            Country  Domain  Sub-Domain        date   type  number
# 0      Afghanistan     NaN         NaN  2016-03-14  Cases   494.0
# 1      Afghanistan     NaN         NaN  2016-03-21  Cases   715.0
# 2      Afghanistan     NaN         NaN  2016-03-28  Cases   704.0
# 3      Afghanistan     NaN         NaN  2016-04-04  Cases   749.0
# 4      Afghanistan     NaN         NaN  2016-04-11  Cases   651.0
# ...            ...     ...         ...         ...    ...     ...
# 68349       Zambia     NaN         NaN  2021-11-29  Cases  1866.0
# 68350       Zambia     NaN         NaN  2021-12-06  Cases  1394.0
# 68351       Zambia     NaN         NaN  2021-12-13  Cases  1348.0
# 68352       Zambia     NaN         NaN  2021-12-20  Cases  1513.0
# 68353       Zambia     NaN         NaN  2021-12-27  Cases  1641.0
#
# [66145 rows x 10 columns]

# %%
world_ilinet_data.to_csv('F:/Pandemic-Database/Past_Pandemic_Time_Series_Data/Influenza/Influenza_World_Weekly_Cases.csv',
                        index = False)

# %% [markdown]
# ### Combine Data

# %%
combined_data = pd.concat([world_ilinet_data,ilinet_data])
combined_data = combined_data.sort_values(by = ['date','Country'])
combined_data
# Out:
#          Microbe Family                Microbe Genus Microbe Species Region  \
# 6875   Orthomyxovididae  Influenza A, B, and C Virus            None   EURO
# 37926  Orthomyxovididae  Influenza A, B, and C Virus            None   EMRO
# 6876   Orthomyxovididae  Influenza A, B, and C Virus            None   EURO
# 37927  Orthomyxovididae  Influenza A, B, and C Virus            None   EMRO
# 6877   Orthomyxovididae  Influenza A, B, and C Virus            None   EURO
# ...                 ...                          ...             ...    ...
# 36828  Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
# 36829  Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
# 36830  Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
# 36831  Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
# 36832  Orthomyxovididae  Influenza A, B, and C Virus            None   AMRO
#
#              Country                                        Domain  \
# 6875         Belgium                                           NaN
# 37926        Morocco                                           NaN
# 6876         Belgium                                           NaN
# 37927        Morocco                                           NaN
# 6877         Belgium                                           NaN
# ...              ...                                           ...
# 36828  United States                                       Wyoming
# 36829  United States  Commonwealth of the Northern Mariana Islands
# 36830  United States                                   Puerto Rico
# 36831  United States                                Virgin Islands
# 36832  United States                                 New York City
#
#        Sub-Domain        date       type  number
# 6875          NaN  2009-01-05      Cases   396.0
# 37926         NaN  2009-01-05      Cases  3407.0
# 6876          NaN  2009-01-12      Cases   992.0
# 37927         NaN  2009-01-12      Cases  3513.0
# 6877          NaN  2009-01-19      Cases  1369.0
# ...           ...         ...        ...     ...
# 36828         NaN  2023-10-23  ILI_Total      68
# 36829         NaN  2023-10-23  ILI_Total       X
# 36830         NaN  2023-10-23  ILI_Total     157
# 36831         NaN  2023-10-23  ILI_Total      22
# 36832         NaN  2023-10-23  ILI_Total    5694
#
# [102978 rows x 10 columns]

# %%
combined_data.to_csv('F:/Pandemic-Database/Past_Pandemic_Time_Series_Data/Influenza/Influenza_World_Domain_Weekly_Cases.csv',
                     index = False)
